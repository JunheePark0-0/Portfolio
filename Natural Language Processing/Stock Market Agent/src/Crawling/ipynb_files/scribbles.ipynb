# %%
print("hello")
# Out:
# Running cells with '.venv (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/SAMSUNG/Desktop/KUBIG/6. 2025 Fall/Multi Agent System/MAS-Briefing/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
